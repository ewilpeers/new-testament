# %% [markdown]
# # init data

# %% [markdown]
# ## datasets

# %%
import pandas as pd

strongs_df = pd.read_csv("strongs.csv")
lv65_df = pd.read_csv("latvian_full65.csv")
import unicodedata
def raccs_common(text):
    d = {
        #ord('\N{COMBINING ACUTE ACCENT}'):None,
        ord('’'): None,  # RIGHT SINGLE QUOTATION MARK
        ord('‘'): None,  # LEFT SINGLE QUOTATION MARK
        ord('“'): None,  # LEFT DOUBLE QUOTATION MARK
        ord('”'): None,  # RIGHT DOUBLE QUOTATION MARK
        ord('['): None,  # LEFT SINGLE QUOTATION MARK
        ord(']'): None,  # RIGHT SINGLE QUOTATION MARK
        ord('-'): None,   # HYPHEN-MINUS
        ord('’'): None,   # HYPHEN-MINUS
        ord('⧼'): None,  # LEFT WHITE ANGLE BRACKET
        ord('⧽'): None,  # RIGHT WHITE ANGLE BRACKET
        ord('*'): None,   # ASTERISK
        ord('⇔'): None,  # LEFT RIGHT DOUBLE ARROW
        ord('〉'): None,  # GREATER-THAN SIGN
        ord('〈'): None,  # LESS-THAN SIGN
        ord('‿'): None,  # LOW LINE
        ord('«'): None,  # LEFT-POINTING DOUBLE ANGLE QUOTATION MARK
        ord('»'): None,  # RIGHT-POINTING DOUBLE ANGLE QUOTATION MARK
        ord('‹'): None,  # SINGLE LEFT-POINTING ANGLE QUOTATION MARK
        ord('›'): None,  # SINGLE RIGHT-POINTING ANGLE QUOTATION MARK
        ord('('): None,  # LEFT PARENTHESIS
        ord(')'): None,  # RIGHT PARENTHESIS
        ord('-') : None,  # HYPHEN-MINUS
        ord(';') : None,  # SEMICOLON
        }
    return unicodedata.normalize('NFC', text).translate(d)
print(strongs_df["form"].apply(raccs_common).head())
# Out:
# 0       Παῦλος
# 1       κλητὸς
# 2    ἀπόστολος
# 3      Χριστοῦ
# 4        Ἰησοῦ
# Name: form, dtype: str

# %% [markdown]
# ## morphology definition

# %%
POS_MAP = {
    "V": "Verb",
    "N": "Noun",
    "Adv": "Adverb",
    "Adj": "Adjective",
    "Art": "Article",
    "DPro": "Demonstrative Pronoun",
    "IPro": "Interrogative / Indefinite Pronoun",
    "PPro": "Personal / Possessive Pronoun",
    "RecPro": "Reciprocal Pronoun",
    "RelPro": "Relative Pronoun",
    "RefPro": "Reflexive Pronoun",
    "Prep": "Preposition",
    "Conj": "Conjunction",
    "I": "Interjection",
    "Prtcl": "Particle",
    "Heb": "Hebrew Word",
    "Aram": "Aramaic Word"
}

PERSON_MAP = {"1": "1st Person", "2": "2nd Person", "3": "3rd Person"}
TENSE_MAP = {"P": "Present", "I": "Imperfect", "F": "Future",
             "A": "Aorist", "R": "Perfect", "L": "Pluperfect"}
MOOD_MAP = {"I": "Indicative", "M": "Imperative",
            "S": "Subjunctive", "O": "Optative",
            "N": "Infinitive", "P": "Participle"}
VOICE_MAP = {"A": "Active", "M": "Middle", "P": "Passive", "M/P": "Middle or Passive"}
CASE_MAP = {"N": "Nominative", "V": "Vocative", "A": "Accusative",
            "G": "Genitive", "D": "Dative"}
NUMBER_MAP = {"S": "Singular", "P": "Plural"}
GENDER_MAP = {"M": "Masculine", "F": "Feminine", "N": "Neuter"}
COMPARISON_MAP = {"C": "Comparative", "S": "Superlative"}

# %%
def parse_morph_code(code):
    if not isinstance(code, str) or not code:
        return {}

    parts = code.split("-")
    pos_key = parts[0]
    
    result = {"part_of_speech": POS_MAP.get(pos_key, pos_key)}

    if len(parts) < 2:
        return result

    # --- VERB LOGIC ---
    if pos_key == "V":
        tmv = parts[1]
        if len(tmv) >= 3:
            result["tense"] = TENSE_MAP.get(tmv[0])
            result["mood"] = MOOD_MAP.get(tmv[1])
            result["voice"] = VOICE_MAP.get(tmv[2])
        
        if len(parts) >= 3:
            third_part = parts[2]
            # FIX: Participles have Case-Gender-Number, not Person-Number
            if result.get("mood") == "Participle":
                for char in third_part:
                    if char in CASE_MAP:
                        result["case"] = CASE_MAP.get(char)
                    elif char in GENDER_MAP:
                        result["gender"] = GENDER_MAP.get(char)
                    elif char in NUMBER_MAP:
                        result["number"] = NUMBER_MAP.get(char)
            else:
                # Finite verbs: Person-Number
                if len(third_part) >= 2:
                    result["person"] = PERSON_MAP.get(third_part[0])
                    result["number"] = NUMBER_MAP.get(third_part[1])
        return result

    # --- NOUN / ADJ / ART / PRONOUN LOGIC ---
    details = parts[1]
    for char in details:
        if char in CASE_MAP:
            result["case"] = CASE_MAP.get(char)
        elif char in GENDER_MAP:
            result["gender"] = GENDER_MAP.get(char)
        elif char in NUMBER_MAP:
            result["number"] = NUMBER_MAP.get(char)
        elif char in COMPARISON_MAP:
            result["comparison"] = COMPARISON_MAP.get(char)
        elif char in PERSON_MAP and "Pro" in pos_key:
            result["person"] = PERSON_MAP.get(char)

    return result

# %%
def build_token_object(row, latvian_words):

    morph_code = row["en_title"]   # your morphology column

    return {
        "greek_form": row["form"],
        "latvian_words": latvian_words,
        "strong_number": row["strong_num"],
        "strong_title": row["strong_title"],
        "morph_code": morph_code,
        "morph_parsed": parse_morph_code(morph_code)
    }

# %% [markdown]
# # build and render

# %% [markdown]
# ## defs

# %%
print(strongs_df.head())
print(lv65_df.head())
# Out:
#    verse  word       form    form_en  strong_num  \
# 0      1     0     Παῦλος       Paul        3972
# 1      1     1     κλητὸς   a called        2822
# 2      1     2  ἀπόστολος    apostle         652
# 3      1     3    Χριστοῦ  of Christ        5547
# 4      1     4      Ἰησοῦ      Jesus        2424
#
#                                         strong_title strong_en_title  \
# 0  3972: Paul, Paulus. Of Latin origin; Paulus, t...           N-NMS
# 1  2822: From the same as klesis; invited, i.e. A...         Adj-NMS
# 2  652: From apostello; a delegate; specially, an...           N-NMS
# 3  5547: Anointed One; the Messiah, the Christ. F...           N-GMS
# 4  2424: Of Hebrew origin; Jesus, the name of our...           N-GMS
#
#     translit                                     translit_title  \
# 0     Paulos  Paulos: Paul, Paulus. Of Latin origin; Paulus,...
# 1     klētos  klētos: From the same as klesis; invited, i.e....
# 2  apostolos  apostolos: From apostello; a delegate; special...
# 3   Christou  Christou: Anointed One; the Messiah, the Chris...
# 4      Iēsou  Iēsou: Of Hebrew origin; Jesus, the name of ou...
#
#             book  chapter
# 0  1_corinthians        1
# 1  1_corinthians        1
# 2  1_corinthians        1
# 3  1_corinthians        1
# 4  1_corinthians        1
#       book  chapter  verse                                               text
# 0  matthew        1      1  Jēzus Kristus Dāvida dēla Ābrahāma dēla cilts ...
# 1  matthew        1      2  Ābrahāms dzemdināja Īzāku Īzāks dzemdināja Jēk...
# 2  matthew        1      3  Un Jūda dzemdināja no Tamāras Ferecu un Caru F...
# 3  matthew        1      4  un Arāms dzemdināja Aminadabu Aminadabs dzemdi...
# 4  matthew        1      5  Salmons dzemdināja no Rahabas Boāsu Boāss dzem...

# %%
import pandas as pd
import time
from pathlib import Path
import json

def prepare_grouped(strongs_df, lv_df):
    strongs_g = strongs_df.groupby(["book", "chapter", "verse"])
    lv_g = lv_df.groupby(["book", "chapter", "verse"])
    return strongs_g, lv_g

def build_verse_object(book, chapter, verse, strongs_g, lv_g):

    key = (book, chapter, verse)

    if key not in strongs_g.groups:
        return None

    if key not in lv_g.groups:
        return None

    strongs_verse = strongs_g.get_group(key)

    latvian_text = lv_g.get_group(key).iloc[0]["text"]
    #print(strongs_verse.sort_values("word"))
    strong_sorted = strongs_verse.sort_values("word")
    strong_data_list = strong_sorted.to_dict("records")
    #print (strong_data_list)
    #return
    greek_text = " ".join(
        strong_sorted["form"].astype(str)
    )
    #greek_text = " ".join([t["form"] for _, t in strongs_verse.sort_values("word").iterrows()])
    
    posfile_path = Path("bible") / str(book) / str(chapter) / f"{book}_{chapter}_{verse}.txt"

    mappings=[]
    leftover_latvian = []
    if posfile_path.exists():
        with open(posfile_path, "r", encoding="utf-8") as f:
            dobj = json.load(f)
        if(dobj.get("locus", None)):
            if(dobj["locus"] != f"{book}_{chapter}_{verse}"):
               raise Exception("does not match!" +" :"+ dobj["locus"] +" " +f"{book}_{chapter}_{verse}")
        if len(strong_sorted) != len(dobj["greek_words"]):
            raise Exception("words lost or excess! at" +" :"+ f"{(book, chapter, verse)}" + "\n db: " + \
                            str(len(strong_sorted)) + " act: " + str(len(dobj["greek_words"])))
        for i in range(len(strong_sorted)):
            gw = dobj['greek_words'][i] #search by index match
            strong_row = strong_data_list[i]
            if int(gw['index']) != i or int(gw['index']) != int(strong_row['word']):
                print(dobj)
                raise Exception("wrong index! Try running python renumber.py ." +" :"+ f"{(book, chapter, verse)}" + " " + str(gw["index"]) + " index should be: " + str(i) + " and in list: " + str(strong_row['word']))
            gw.update({
                "strong_num": strong_row.get("strong_num"),
                "form": strong_row.get("form"),
                "translit_title": strong_row.get("translit_title"),
                "translit": strong_row.get("translit"),
                "strong_en_title": strong_row.get("strong_en_title")
            })
            
            mappings.append(gw)
        leftover_latvian = dobj.get("leftover_latvian", [])
    else:
        print("File does not exist:", posfile_path)

    return {
        "book": book,
        "chapter": chapter,
        "verse": verse,
        "greek_text": greek_text,
        "latvian_text": latvian_text,
        "mappings": mappings,
        "leftover_latvian": leftover_latvian
    }


def process_book_full(book, strongs_g, lv_g, exclude_list=[], startatchap=1, stopatchap=-1):
    results = []
    total_start = time.perf_counter()   # ⏳ start total timer
    # Drive iteration from Latvian (verse-level dataset)
    keyss = sorted(lv_g.groups.keys())
    for i, key in enumerate(keyss):
        b, chapter, verse = key
        if b != book:
            continue
        
        if key in exclude_list:
            continue

        #current chunk limit
        if stopatchap>0 and chapter >= stopatchap:
            break

        if startatchap>0 and chapter < startatchap:
            continue

        result = build_verse_object(b, chapter, verse, strongs_g, lv_g)

        results.append(result)

        #if len(results) >30:
        #    break

    return results

#cache index
strongs_g, lv_g = prepare_grouped(strongs_df, lv65_df)

# %% [markdown]
# ## doit

# %%
ex_list = []
ex_list = [("john", 1, i) for i in range (1, 51+1)] # if i != 42]
ex_list.extend([("john", 2, i) for i in range (1, 25+1)])
ex_list.extend([("john", 3, i) for i in range (1, 36+1)])
ex_list.extend([("john", 4, i) for i in range (1, 54+1)])
ex_list.extend([("john", 5, i) for i in range (1, 47+1)])
ex_list.extend([("john", 6, i) for i in range (1, 71+1)])
ex_list.extend([("john", 7, i) for i in range (1, 53+1)])
ex_list.extend([("john", 8, i) for i in range (1, 59+1)])
#ex_list.extend([("john", 12, 38)])
#ex_list.extend([("john", 12, 49)])
#ex_list.extend([("john", 15, 23)])
#ex_list.extend([("john", 18, 2)])
#ex_list.extend([("john", 18, 40)])
data = process_book_full(
    "john",
    strongs_g,
    lv_g,
    ex_list,
    -1,
    -1
)

# %%
curchap = 16
data = process_book_full(
    "mark",
    strongs_g,
    lv_g,
    ex_list,
    curchap,
    curchap+1
)
# 8 9

# %%
curchap = -2
data = process_book_full(
    "matthew",
    strongs_g,
    lv_g,
    ex_list,
    curchap,
    curchap+1
)
# Out:
# File does not exist: bible/matthew/10/matthew_10_1.txt
# File does not exist: bible/matthew/10/matthew_10_2.txt
# File does not exist: bible/matthew/10/matthew_10_3.txt
# File does not exist: bible/matthew/10/matthew_10_4.txt
# File does not exist: bible/matthew/10/matthew_10_5.txt
# File does not exist: bible/matthew/10/matthew_10_6.txt
# File does not exist: bible/matthew/10/matthew_10_7.txt
# File does not exist: bible/matthew/10/matthew_10_8.txt
# File does not exist: bible/matthew/10/matthew_10_9.txt
# File does not exist: bible/matthew/10/matthew_10_10.txt
# File does not exist: bible/matthew/10/matthew_10_11.txt
# File does not exist: bible/matthew/10/matthew_10_12.txt
# File does not exist: bible/matthew/10/matthew_10_13.txt
# File does not exist: bible/matthew/10/matthew_10_14.txt
# File does not exist: bible/matthew/10/matthew_10_15.txt
# File does not exist: bible/matthew/10/matthew_10_16.txt
# File does not exist: bible/matthew/10/matthew_10_17.txt
# File does not exist: bible/matthew/10/matthew_10_18.txt
# File does not exist: bible/matthew/10/matthew_10_19.txt
# File does not exist: bible/matthew/10/matthew_10_20.txt
# File does not exist: bible/matthew/10/matthew_10_21.txt
# File does not exist: bible/matthew/10/matthew_10_22.txt
# File does not exist: bible/matthew/10/matthew_10_23.txt
# File does not exist: bible/matthew/10/matthew_10_24.txt
# File does not exist: bible/matthew/10/matthew_10_25.txt
# File does not exist: bible/matthew/10/matthew_10_26.txt
# File does not exist: bible/matthew/10/matthew_10_27.txt
# File does not exist: bible/matthew/10/matthew_10_28.txt
# File does not exist: bible/matthew/10/matthew_10_29.txt
# File does not exist: bible/matthew/10/matthew_10_30.txt
# File does not exist: bible/matthew/10/matthew_10_31.txt
# File does not exist: bible/matthew/10/matthew_10_32.txt
# File does not exist: bible/matthew/10/matthew_10_33.txt
# File does not exist: bible/matthew/10/matthew_10_34.txt
# File does not exist: bible/matthew/10/matthew_10_35.txt
# File does not exist: bible/matthew/10/matthew_10_36.txt
# File does not exist: bible/matthew/10/matthew_10_37.txt
# File does not exist: bible/matthew/10/matthew_10_38.txt
# File does not exist: bible/matthew/10/matthew_10_39.txt
# File does not exist: bible/matthew/10/matthew_10_40.txt
# File does not exist: bible/matthew/10/matthew_10_41.txt
# File does not exist: bible/matthew/10/matthew_10_42.txt
# File does not exist: bible/matthew/11/matthew_11_1.txt
# File does not exist: bible/matthew/11/matthew_11_2.txt
# File does not exist: bible/matthew/11/matthew_11_3.txt
# File does not exist: bible/matthew/11/matthew_11_4.txt
# File does not exist: bible/matthew/11/matthew_11_5.txt
# File does not exist: bible/matthew/11/matthew_11_6.txt
# File does not exist: bible/matthew/11/matthew_11_7.txt
# File does not exist: bible/matthew/11/matthew_11_8.txt
# File does not exist: bible/matthew/11/matthew_11_9.txt
# File does not exist: bible/matthew/11/matthew_11_10.txt
# File does not exist: bible/matthew/11/matthew_11_11.txt
# File does not exist: bible/matthew/11/matthew_11_12.txt
# File does not exist: bible/matthew/11/matthew_11_13.txt
# File does not exist: bible/matthew/11/matthew_11_14.txt
# File does not exist: bible/matthew/11/matthew_11_15.txt
# File does not exist: bible/matthew/11/matthew_11_16.txt
# File does not exist: bible/matthew/11/matthew_11_17.txt
# File does not exist: bible/matthew/11/matthew_11_18.txt
# File does not exist: bible/matthew/11/matthew_11_19.txt
# File does not exist: bible/matthew/11/matthew_11_20.txt
# File does not exist: bible/matthew/11/matthew_11_21.txt
# File does not exist: bible/matthew/11/matthew_11_22.txt
# File does not exist: bible/matthew/11/matthew_11_23.txt
# File does not exist: bible/matthew/11/matthew_11_24.txt
# File does not exist: bible/matthew/11/matthew_11_25.txt
# File does not exist: bible/matthew/11/matthew_11_26.txt
# File does not exist: bible/matthew/11/matthew_11_27.txt
# File does not exist: bible/matthew/11/matthew_11_28.txt
# File does not exist: bible/matthew/11/matthew_11_29.txt
# File does not exist: bible/matthew/11/matthew_11_30.txt
# File does not exist: bible/matthew/12/matthew_12_1.txt
# File does not exist: bible/matthew/12/matthew_12_2.txt
# File does not exist: bible/matthew/12/matthew_12_3.txt
# File does not exist: bible/matthew/12/matthew_12_4.txt
# File does not exist: bible/matthew/12/matthew_12_5.txt
# File does not exist: bible/matthew/12/matthew_12_6.txt
# File does not exist: bible/matthew/12/matthew_12_7.txt
# File does not exist: bible/matthew/12/matthew_12_8.txt
# File does not exist: bible/matthew/12/matthew_12_9.txt
# File does not exist: bible/matthew/12/matthew_12_10.txt
# File does not exist: bible/matthew/12/matthew_12_11.txt
# File does not exist: bible/matthew/12/matthew_12_12.txt
# File does not exist: bible/matthew/12/matthew_12_13.txt
# File does not exist: bible/matthew/12/matthew_12_14.txt
# File does not exist: bible/matthew/12/matthew_12_15.txt
# File does not exist: bible/matthew/12/matthew_12_16.txt
# File does not exist: bible/matthew/12/matthew_12_17.txt
# File does not exist: bible/matthew/12/matthew_12_18.txt
# File does not exist: bible/matthew/12/matthew_12_19.txt
# File does not exist: bible/matthew/12/matthew_12_20.txt
# File does not exist: bible/matthew/12/matthew_12_21.txt
# File does not exist: bible/matthew/12/matthew_12_22.txt
# File does not exist: bible/matthew/12/matthew_12_23.txt
# File does not exist: bible/matthew/12/matthew_12_24.txt
# File does not exist: bible/matthew/12/matthew_12_25.txt
# File does not exist: bible/matthew/12/matthew_12_26.txt
# File does not exist: bible/matthew/12/matthew_12_27.txt
# File does not exist: bible/matthew/12/matthew_12_28.txt
# File does not exist: bible/matthew/12/matthew_12_29.txt
# File does not exist: bible/matthew/12/matthew_12_30.txt
# File does not exist: bible/matthew/12/matthew_12_31.txt
# File does not exist: bible/matthew/12/matthew_12_32.txt
# File does not exist: bible/matthew/12/matthew_12_33.txt
# File does not exist: bible/matthew/12/matthew_12_34.txt
# File does not exist: bible/matthew/12/matthew_12_35.txt
# File does not exist: bible/matthew/12/matthew_12_36.txt
# File does not exist: bible/matthew/12/matthew_12_37.txt
# File does not exist: bible/matthew/12/matthew_12_38.txt
# File does not exist: bible/matthew/12/matthew_12_39.txt
# File does not exist: bible/matthew/12/matthew_12_40.txt
# File does not exist: bible/matthew/12/matthew_12_41.txt
# File does not exist: bible/matthew/12/matthew_12_42.txt
# File does not exist: bible/matthew/12/matthew_12_43.txt
# File does not exist: bible/matthew/12/matthew_12_44.txt
# File does not exist: bible/matthew/12/matthew_12_45.txt
# File does not exist: bible/matthew/12/matthew_12_46.txt
# File does not exist: bible/matthew/12/matthew_12_47.txt
# File does not exist: bible/matthew/12/matthew_12_48.txt
# File does not exist: bible/matthew/12/matthew_12_49.txt
# File does not exist: bible/matthew/12/matthew_12_50.txt
# File does not exist: bible/matthew/13/matthew_13_1.txt
# File does not exist: bible/matthew/13/matthew_13_2.txt
# File does not exist: bible/matthew/13/matthew_13_3.txt
# File does not exist: bible/matthew/13/matthew_13_4.txt
# File does not exist: bible/matthew/13/matthew_13_5.txt
# File does not exist: bible/matthew/13/matthew_13_6.txt
# File does not exist: bible/matthew/13/matthew_13_7.txt
# File does not exist: bible/matthew/13/matthew_13_8.txt
# File does not exist: bible/matthew/13/matthew_13_9.txt
# File does not exist: bible/matthew/13/matthew_13_10.txt
# File does not exist: bible/matthew/13/matthew_13_11.txt
# File does not exist: bible/matthew/13/matthew_13_12.txt
# File does not exist: bible/matthew/13/matthew_13_13.txt
# File does not exist: bible/matthew/13/matthew_13_14.txt
# File does not exist: bible/matthew/13/matthew_13_15.txt
# File does not exist: bible/matthew/13/matthew_13_16.txt
# File does not exist: bible/matthew/13/matthew_13_17.txt
# File does not exist: bible/matthew/13/matthew_13_18.txt
# File does not exist: bible/matthew/13/matthew_13_19.txt
# File does not exist: bible/matthew/13/matthew_13_20.txt
# File does not exist: bible/matthew/13/matthew_13_21.txt
# File does not exist: bible/matthew/13/matthew_13_22.txt
# File does not exist: bible/matthew/13/matthew_13_23.txt
# File does not exist: bible/matthew/13/matthew_13_24.txt
# File does not exist: bible/matthew/13/matthew_13_25.txt
# File does not exist: bible/matthew/13/matthew_13_26.txt
# File does not exist: bible/matthew/13/matthew_13_27.txt
# File does not exist: bible/matthew/13/matthew_13_28.txt
# File does not exist: bible/matthew/13/matthew_13_29.txt
# File does not exist: bible/matthew/13/matthew_13_30.txt
# File does not exist: bible/matthew/13/matthew_13_31.txt
# File does not exist: bible/matthew/13/matthew_13_32.txt
# File does not exist: bible/matthew/13/matthew_13_33.txt
# File does not exist: bible/matthew/13/matthew_13_34.txt
# File does not exist: bible/matthew/13/matthew_13_35.txt
# File does not exist: bible/matthew/13/matthew_13_36.txt
# File does not exist: bible/matthew/13/matthew_13_37.txt
# File does not exist: bible/matthew/13/matthew_13_38.txt
# File does not exist: bible/matthew/13/matthew_13_39.txt
# File does not exist: bible/matthew/13/matthew_13_40.txt
# File does not exist: bible/matthew/13/matthew_13_41.txt
# File does not exist: bible/matthew/13/matthew_13_42.txt
# File does not exist: bible/matthew/13/matthew_13_43.txt
# File does not exist: bible/matthew/13/matthew_13_44.txt
# File does not exist: bible/matthew/13/matthew_13_45.txt
# File does not exist: bible/matthew/13/matthew_13_46.txt
# File does not exist: bible/matthew/13/matthew_13_47.txt
# File does not exist: bible/matthew/13/matthew_13_48.txt
# File does not exist: bible/matthew/13/matthew_13_49.txt
# File does not exist: bible/matthew/13/matthew_13_50.txt
# File does not exist: bible/matthew/13/matthew_13_51.txt
# File does not exist: bible/matthew/13/matthew_13_52.txt
# File does not exist: bible/matthew/13/matthew_13_53.txt
# File does not exist: bible/matthew/13/matthew_13_54.txt
# File does not exist: bible/matthew/13/matthew_13_55.txt
# File does not exist: bible/matthew/13/matthew_13_56.txt
# File does not exist: bible/matthew/13/matthew_13_57.txt
# File does not exist: bible/matthew/13/matthew_13_58.txt
# File does not exist: bible/matthew/14/matthew_14_1.txt
# File does not exist: bible/matthew/14/matthew_14_2.txt
# File does not exist: bible/matthew/14/matthew_14_3.txt
# File does not exist: bible/matthew/14/matthew_14_4.txt
# File does not exist: bible/matthew/14/matthew_14_5.txt
# File does not exist: bible/matthew/14/matthew_14_6.txt
# File does not exist: bible/matthew/14/matthew_14_7.txt
# File does not exist: bible/matthew/14/matthew_14_8.txt
# File does not exist: bible/matthew/14/matthew_14_9.txt
# File does not exist: bible/matthew/14/matthew_14_10.txt
# File does not exist: bible/matthew/14/matthew_14_11.txt
# File does not exist: bible/matthew/14/matthew_14_12.txt
# File does not exist: bible/matthew/14/matthew_14_13.txt
# File does not exist: bible/matthew/14/matthew_14_14.txt
# File does not exist: bible/matthew/14/matthew_14_15.txt
# File does not exist: bible/matthew/14/matthew_14_16.txt
# File does not exist: bible/matthew/14/matthew_14_17.txt
# File does not exist: bible/matthew/14/matthew_14_18.txt
# File does not exist: bible/matthew/14/matthew_14_19.txt
# File does not exist: bible/matthew/14/matthew_14_20.txt
# File does not exist: bible/matthew/14/matthew_14_21.txt
# File does not exist: bible/matthew/14/matthew_14_22.txt
# File does not exist: bible/matthew/14/matthew_14_23.txt
# File does not exist: bible/matthew/14/matthew_14_24.txt
# File does not exist: bible/matthew/14/matthew_14_25.txt
# File does not exist: bible/matthew/14/matthew_14_26.txt
# File does not exist: bible/matthew/14/matthew_14_27.txt
# File does not exist: bible/matthew/14/matthew_14_28.txt
# File does not exist: bible/matthew/14/matthew_14_29.txt
# File does not exist: bible/matthew/14/matthew_14_30.txt
# File does not exist: bible/matthew/14/matthew_14_31.txt
# File does not exist: bible/matthew/14/matthew_14_32.txt
# File does not exist: bible/matthew/14/matthew_14_33.txt
# File does not exist: bible/matthew/14/matthew_14_34.txt
# File does not exist: bible/matthew/14/matthew_14_35.txt
# File does not exist: bible/matthew/14/matthew_14_36.txt
# File does not exist: bible/matthew/15/matthew_15_1.txt
# File does not exist: bible/matthew/15/matthew_15_2.txt
# File does not exist: bible/matthew/15/matthew_15_3.txt
# File does not exist: bible/matthew/15/matthew_15_4.txt
# File does not exist: bible/matthew/15/matthew_15_5.txt
# File does not exist: bible/matthew/15/matthew_15_6.txt
# File does not exist: bible/matthew/15/matthew_15_7.txt
# File does not exist: bible/matthew/15/matthew_15_8.txt
# File does not exist: bible/matthew/15/matthew_15_9.txt
# File does not exist: bible/matthew/15/matthew_15_10.txt
# File does not exist: bible/matthew/15/matthew_15_11.txt
# File does not exist: bible/matthew/15/matthew_15_12.txt
# File does not exist: bible/matthew/15/matthew_15_13.txt
# File does not exist: bible/matthew/15/matthew_15_14.txt
# File does not exist: bible/matthew/15/matthew_15_15.txt
# File does not exist: bible/matthew/15/matthew_15_16.txt
# File does not exist: bible/matthew/15/matthew_15_17.txt
# File does not exist: bible/matthew/15/matthew_15_18.txt
# File does not exist: bible/matthew/15/matthew_15_19.txt
# File does not exist: bible/matthew/15/matthew_15_20.txt
# File does not exist: bible/matthew/15/matthew_15_21.txt
# File does not exist: bible/matthew/15/matthew_15_22.txt
# File does not exist: bible/matthew/15/matthew_15_23.txt
# File does not exist: bible/matthew/15/matthew_15_24.txt
# File does not exist: bible/matthew/15/matthew_15_25.txt
# File does not exist: bible/matthew/15/matthew_15_26.txt
# File does not exist: bible/matthew/15/matthew_15_27.txt
# File does not exist: bible/matthew/15/matthew_15_28.txt
# File does not exist: bible/matthew/15/matthew_15_29.txt
# File does not exist: bible/matthew/15/matthew_15_30.txt
# File does not exist: bible/matthew/15/matthew_15_31.txt
# File does not exist: bible/matthew/15/matthew_15_32.txt
# File does not exist: bible/matthew/15/matthew_15_33.txt
# File does not exist: bible/matthew/15/matthew_15_34.txt
# File does not exist: bible/matthew/15/matthew_15_35.txt
# File does not exist: bible/matthew/15/matthew_15_36.txt
# File does not exist: bible/matthew/15/matthew_15_37.txt
# File does not exist: bible/matthew/15/matthew_15_38.txt
# File does not exist: bible/matthew/15/matthew_15_39.txt
# File does not exist: bible/matthew/16/matthew_16_1.txt
# File does not exist: bible/matthew/16/matthew_16_2.txt
# File does not exist: bible/matthew/16/matthew_16_3.txt
# File does not exist: bible/matthew/16/matthew_16_4.txt
# File does not exist: bible/matthew/16/matthew_16_5.txt
# File does not exist: bible/matthew/16/matthew_16_6.txt
# File does not exist: bible/matthew/16/matthew_16_7.txt
# File does not exist: bible/matthew/16/matthew_16_8.txt
# File does not exist: bible/matthew/16/matthew_16_9.txt
# File does not exist: bible/matthew/16/matthew_16_10.txt
# File does not exist: bible/matthew/16/matthew_16_11.txt
# File does not exist: bible/matthew/16/matthew_16_12.txt
# File does not exist: bible/matthew/16/matthew_16_13.txt
# File does not exist: bible/matthew/16/matthew_16_14.txt
# File does not exist: bible/matthew/16/matthew_16_15.txt
# File does not exist: bible/matthew/16/matthew_16_16.txt
# File does not exist: bible/matthew/16/matthew_16_17.txt
# File does not exist: bible/matthew/16/matthew_16_18.txt
# File does not exist: bible/matthew/16/matthew_16_19.txt
# File does not exist: bible/matthew/16/matthew_16_20.txt
# File does not exist: bible/matthew/16/matthew_16_21.txt
# File does not exist: bible/matthew/16/matthew_16_22.txt
# File does not exist: bible/matthew/16/matthew_16_23.txt
# File does not exist: bible/matthew/16/matthew_16_24.txt
# File does not exist: bible/matthew/16/matthew_16_25.txt
# File does not exist: bible/matthew/16/matthew_16_26.txt
# File does not exist: bible/matthew/16/matthew_16_27.txt
# File does not exist: bible/matthew/16/matthew_16_28.txt
# File does not exist: bible/matthew/17/matthew_17_1.txt
# File does not exist: bible/matthew/17/matthew_17_2.txt
# File does not exist: bible/matthew/17/matthew_17_3.txt
# File does not exist: bible/matthew/17/matthew_17_4.txt
# File does not exist: bible/matthew/17/matthew_17_5.txt
# File does not exist: bible/matthew/17/matthew_17_6.txt
# File does not exist: bible/matthew/17/matthew_17_7.txt
# File does not exist: bible/matthew/17/matthew_17_8.txt
# File does not exist: bible/matthew/17/matthew_17_9.txt
# File does not exist: bible/matthew/17/matthew_17_10.txt
# File does not exist: bible/matthew/17/matthew_17_11.txt
# File does not exist: bible/matthew/17/matthew_17_12.txt
# File does not exist: bible/matthew/17/matthew_17_13.txt
# File does not exist: bible/matthew/17/matthew_17_14.txt
# File does not exist: bible/matthew/17/matthew_17_15.txt
# File does not exist: bible/matthew/17/matthew_17_16.txt
# File does not exist: bible/matthew/17/matthew_17_17.txt
# File does not exist: bible/matthew/17/matthew_17_18.txt
# File does not exist: bible/matthew/17/matthew_17_19.txt
# File does not exist: bible/matthew/17/matthew_17_20.txt
# File does not exist: bible/matthew/17/matthew_17_21.txt
# File does not exist: bible/matthew/17/matthew_17_22.txt
# File does not exist: bible/matthew/17/matthew_17_23.txt
# File does not exist: bible/matthew/17/matthew_17_24.txt
# File does not exist: bible/matthew/17/matthew_17_25.txt
# File does not exist: bible/matthew/17/matthew_17_26.txt
# File does not exist: bible/matthew/17/matthew_17_27.txt
# File does not exist: bible/matthew/18/matthew_18_1.txt
# File does not exist: bible/matthew/18/matthew_18_2.txt
# File does not exist: bible/matthew/18/matthew_18_3.txt
# File does not exist: bible/matthew/18/matthew_18_4.txt
# File does not exist: bible/matthew/18/matthew_18_5.txt
# File does not exist: bible/matthew/18/matthew_18_6.txt
# File does not exist: bible/matthew/18/matthew_18_7.txt
# File does not exist: bible/matthew/18/matthew_18_8.txt
# File does not exist: bible/matthew/18/matthew_18_9.txt
# File does not exist: bible/matthew/18/matthew_18_10.txt
# File does not exist: bible/matthew/18/matthew_18_11.txt
# File does not exist: bible/matthew/18/matthew_18_12.txt
# File does not exist: bible/matthew/18/matthew_18_13.txt
# File does not exist: bible/matthew/18/matthew_18_14.txt
# File does not exist: bible/matthew/18/matthew_18_15.txt
# File does not exist: bible/matthew/18/matthew_18_16.txt
# File does not exist: bible/matthew/18/matthew_18_17.txt
# File does not exist: bible/matthew/18/matthew_18_18.txt
# File does not exist: bible/matthew/18/matthew_18_19.txt
# File does not exist: bible/matthew/18/matthew_18_20.txt
# File does not exist: bible/matthew/18/matthew_18_21.txt
# File does not exist: bible/matthew/18/matthew_18_22.txt
# File does not exist: bible/matthew/18/matthew_18_23.txt
# File does not exist: bible/matthew/18/matthew_18_24.txt
# File does not exist: bible/matthew/18/matthew_18_25.txt
# File does not exist: bible/matthew/18/matthew_18_26.txt
# File does not exist: bible/matthew/18/matthew_18_27.txt
# File does not exist: bible/matthew/18/matthew_18_28.txt
# File does not exist: bible/matthew/18/matthew_18_29.txt
# File does not exist: bible/matthew/18/matthew_18_30.txt
# File does not exist: bible/matthew/18/matthew_18_31.txt
# File does not exist: bible/matthew/18/matthew_18_32.txt
# File does not exist: bible/matthew/18/matthew_18_33.txt
# File does not exist: bible/matthew/18/matthew_18_34.txt
# File does not exist: bible/matthew/18/matthew_18_35.txt
# File does not exist: bible/matthew/19/matthew_19_1.txt
# File does not exist: bible/matthew/19/matthew_19_2.txt
# File does not exist: bible/matthew/19/matthew_19_3.txt
# File does not exist: bible/matthew/19/matthew_19_4.txt
# File does not exist: bible/matthew/19/matthew_19_5.txt
# File does not exist: bible/matthew/19/matthew_19_6.txt
# File does not exist: bible/matthew/19/matthew_19_7.txt
# File does not exist: bible/matthew/19/matthew_19_8.txt
# File does not exist: bible/matthew/19/matthew_19_9.txt
# File does not exist: bible/matthew/19/matthew_19_10.txt
# File does not exist: bible/matthew/19/matthew_19_11.txt
# File does not exist: bible/matthew/19/matthew_19_12.txt
# File does not exist: bible/matthew/19/matthew_19_13.txt
# File does not exist: bible/matthew/19/matthew_19_14.txt
# File does not exist: bible/matthew/19/matthew_19_15.txt
# File does not exist: bible/matthew/19/matthew_19_16.txt
# File does not exist: bible/matthew/19/matthew_19_17.txt
# File does not exist: bible/matthew/19/matthew_19_18.txt
# File does not exist: bible/matthew/19/matthew_19_19.txt
# File does not exist: bible/matthew/19/matthew_19_20.txt
# File does not exist: bible/matthew/19/matthew_19_21.txt
# File does not exist: bible/matthew/19/matthew_19_22.txt
# File does not exist: bible/matthew/19/matthew_19_23.txt
# File does not exist: bible/matthew/19/matthew_19_24.txt
# File does not exist: bible/matthew/19/matthew_19_25.txt
# File does not exist: bible/matthew/19/matthew_19_26.txt
# File does not exist: bible/matthew/19/matthew_19_27.txt
# File does not exist: bible/matthew/19/matthew_19_28.txt
# File does not exist: bible/matthew/19/matthew_19_29.txt
# File does not exist: bible/matthew/19/matthew_19_30.txt
# File does not exist: bible/matthew/20/matthew_20_1.txt
# File does not exist: bible/matthew/20/matthew_20_2.txt
# File does not exist: bible/matthew/20/matthew_20_3.txt
# File does not exist: bible/matthew/20/matthew_20_4.txt
# File does not exist: bible/matthew/20/matthew_20_5.txt
# File does not exist: bible/matthew/20/matthew_20_6.txt
# File does not exist: bible/matthew/20/matthew_20_7.txt
# File does not exist: bible/matthew/20/matthew_20_8.txt
# File does not exist: bible/matthew/20/matthew_20_9.txt
# File does not exist: bible/matthew/20/matthew_20_10.txt
# File does not exist: bible/matthew/20/matthew_20_11.txt
# File does not exist: bible/matthew/20/matthew_20_12.txt
# File does not exist: bible/matthew/20/matthew_20_13.txt
# File does not exist: bible/matthew/20/matthew_20_14.txt
# File does not exist: bible/matthew/20/matthew_20_15.txt
# File does not exist: bible/matthew/20/matthew_20_16.txt
# File does not exist: bible/matthew/20/matthew_20_17.txt
# File does not exist: bible/matthew/20/matthew_20_18.txt
# File does not exist: bible/matthew/20/matthew_20_19.txt
# File does not exist: bible/matthew/20/matthew_20_20.txt
# File does not exist: bible/matthew/20/matthew_20_21.txt
# File does not exist: bible/matthew/20/matthew_20_22.txt
# File does not exist: bible/matthew/20/matthew_20_23.txt
# File does not exist: bible/matthew/20/matthew_20_24.txt
# File does not exist: bible/matthew/20/matthew_20_25.txt
# File does not exist: bible/matthew/20/matthew_20_26.txt
# File does not exist: bible/matthew/20/matthew_20_27.txt
# File does not exist: bible/matthew/20/matthew_20_28.txt
# File does not exist: bible/matthew/20/matthew_20_29.txt
# File does not exist: bible/matthew/20/matthew_20_30.txt
# File does not exist: bible/matthew/20/matthew_20_31.txt
# File does not exist: bible/matthew/20/matthew_20_32.txt
# File does not exist: bible/matthew/20/matthew_20_33.txt
# File does not exist: bible/matthew/20/matthew_20_34.txt
# File does not exist: bible/matthew/21/matthew_21_1.txt
# File does not exist: bible/matthew/21/matthew_21_2.txt
# File does not exist: bible/matthew/21/matthew_21_3.txt
# File does not exist: bible/matthew/21/matthew_21_4.txt
# File does not exist: bible/matthew/21/matthew_21_5.txt
# File does not exist: bible/matthew/21/matthew_21_6.txt
# File does not exist: bible/matthew/21/matthew_21_7.txt
# File does not exist: bible/matthew/21/matthew_21_8.txt
# File does not exist: bible/matthew/21/matthew_21_9.txt
# File does not exist: bible/matthew/21/matthew_21_10.txt
# File does not exist: bible/matthew/21/matthew_21_11.txt
# File does not exist: bible/matthew/21/matthew_21_12.txt
# File does not exist: bible/matthew/21/matthew_21_13.txt
# File does not exist: bible/matthew/21/matthew_21_14.txt
# File does not exist: bible/matthew/21/matthew_21_15.txt
# File does not exist: bible/matthew/21/matthew_21_16.txt
# File does not exist: bible/matthew/21/matthew_21_17.txt
# File does not exist: bible/matthew/21/matthew_21_18.txt
# File does not exist: bible/matthew/21/matthew_21_19.txt
# File does not exist: bible/matthew/21/matthew_21_20.txt
# File does not exist: bible/matthew/21/matthew_21_21.txt
# File does not exist: bible/matthew/21/matthew_21_22.txt
# File does not exist: bible/matthew/21/matthew_21_23.txt
# File does not exist: bible/matthew/21/matthew_21_24.txt
# File does not exist: bible/matthew/21/matthew_21_25.txt
# File does not exist: bible/matthew/21/matthew_21_26.txt
# File does not exist: bible/matthew/21/matthew_21_27.txt
# File does not exist: bible/matthew/21/matthew_21_28.txt
# File does not exist: bible/matthew/21/matthew_21_29.txt
# File does not exist: bible/matthew/21/matthew_21_30.txt
# File does not exist: bible/matthew/21/matthew_21_31.txt
# File does not exist: bible/matthew/21/matthew_21_32.txt
# File does not exist: bible/matthew/21/matthew_21_33.txt
# File does not exist: bible/matthew/21/matthew_21_34.txt
# File does not exist: bible/matthew/21/matthew_21_35.txt
# File does not exist: bible/matthew/21/matthew_21_36.txt
# File does not exist: bible/matthew/21/matthew_21_37.txt
# File does not exist: bible/matthew/21/matthew_21_38.txt
# File does not exist: bible/matthew/21/matthew_21_39.txt
# File does not exist: bible/matthew/21/matthew_21_40.txt
# File does not exist: bible/matthew/21/matthew_21_41.txt
# File does not exist: bible/matthew/21/matthew_21_42.txt
# File does not exist: bible/matthew/21/matthew_21_43.txt
# File does not exist: bible/matthew/21/matthew_21_44.txt
# File does not exist: bible/matthew/21/matthew_21_45.txt
# File does not exist: bible/matthew/21/matthew_21_46.txt
# File does not exist: bible/matthew/22/matthew_22_1.txt
# File does not exist: bible/matthew/22/matthew_22_2.txt
# File does not exist: bible/matthew/22/matthew_22_3.txt
# File does not exist: bible/matthew/22/matthew_22_4.txt
# File does not exist: bible/matthew/22/matthew_22_5.txt
# File does not exist: bible/matthew/22/matthew_22_6.txt
# File does not exist: bible/matthew/22/matthew_22_7.txt
# File does not exist: bible/matthew/22/matthew_22_8.txt
# File does not exist: bible/matthew/22/matthew_22_9.txt
# File does not exist: bible/matthew/22/matthew_22_10.txt
# File does not exist: bible/matthew/22/matthew_22_11.txt
# File does not exist: bible/matthew/22/matthew_22_12.txt
# File does not exist: bible/matthew/22/matthew_22_13.txt
# File does not exist: bible/matthew/22/matthew_22_14.txt
# File does not exist: bible/matthew/22/matthew_22_15.txt
# File does not exist: bible/matthew/22/matthew_22_16.txt
# File does not exist: bible/matthew/22/matthew_22_17.txt
# File does not exist: bible/matthew/22/matthew_22_18.txt
# File does not exist: bible/matthew/22/matthew_22_19.txt
# File does not exist: bible/matthew/22/matthew_22_20.txt
# File does not exist: bible/matthew/22/matthew_22_21.txt
# File does not exist: bible/matthew/22/matthew_22_22.txt
# File does not exist: bible/matthew/22/matthew_22_23.txt
# File does not exist: bible/matthew/22/matthew_22_24.txt
# File does not exist: bible/matthew/22/matthew_22_25.txt
# File does not exist: bible/matthew/22/matthew_22_26.txt
# File does not exist: bible/matthew/22/matthew_22_27.txt
# File does not exist: bible/matthew/22/matthew_22_28.txt
# File does not exist: bible/matthew/22/matthew_22_29.txt
# File does not exist: bible/matthew/22/matthew_22_30.txt
# File does not exist: bible/matthew/22/matthew_22_31.txt
# File does not exist: bible/matthew/22/matthew_22_32.txt
# File does not exist: bible/matthew/22/matthew_22_33.txt
# File does not exist: bible/matthew/22/matthew_22_34.txt
# File does not exist: bible/matthew/22/matthew_22_35.txt
# File does not exist: bible/matthew/22/matthew_22_36.txt
# File does not exist: bible/matthew/22/matthew_22_37.txt
# File does not exist: bible/matthew/22/matthew_22_38.txt
# File does not exist: bible/matthew/22/matthew_22_39.txt
# File does not exist: bible/matthew/22/matthew_22_40.txt
# File does not exist: bible/matthew/22/matthew_22_41.txt
# File does not exist: bible/matthew/22/matthew_22_42.txt
# File does not exist: bible/matthew/22/matthew_22_43.txt
# File does not exist: bible/matthew/22/matthew_22_44.txt
# File does not exist: bible/matthew/22/matthew_22_45.txt
# File does not exist: bible/matthew/22/matthew_22_46.txt
# File does not exist: bible/matthew/23/matthew_23_1.txt
# File does not exist: bible/matthew/23/matthew_23_2.txt
# File does not exist: bible/matthew/23/matthew_23_3.txt
# File does not exist: bible/matthew/23/matthew_23_4.txt
# File does not exist: bible/matthew/23/matthew_23_5.txt
# File does not exist: bible/matthew/23/matthew_23_6.txt
# File does not exist: bible/matthew/23/matthew_23_7.txt
# File does not exist: bible/matthew/23/matthew_23_8.txt
# File does not exist: bible/matthew/23/matthew_23_9.txt
# File does not exist: bible/matthew/23/matthew_23_10.txt
# File does not exist: bible/matthew/23/matthew_23_11.txt
# File does not exist: bible/matthew/23/matthew_23_12.txt
# File does not exist: bible/matthew/23/matthew_23_13.txt
# File does not exist: bible/matthew/23/matthew_23_14.txt
# File does not exist: bible/matthew/23/matthew_23_15.txt
# File does not exist: bible/matthew/23/matthew_23_16.txt
# File does not exist: bible/matthew/23/matthew_23_17.txt
# File does not exist: bible/matthew/23/matthew_23_18.txt
# File does not exist: bible/matthew/23/matthew_23_19.txt
# File does not exist: bible/matthew/23/matthew_23_20.txt
# File does not exist: bible/matthew/23/matthew_23_21.txt
# File does not exist: bible/matthew/23/matthew_23_22.txt
# File does not exist: bible/matthew/23/matthew_23_23.txt
# File does not exist: bible/matthew/23/matthew_23_24.txt
# File does not exist: bible/matthew/23/matthew_23_25.txt
# File does not exist: bible/matthew/23/matthew_23_26.txt
# File does not exist: bible/matthew/23/matthew_23_27.txt
# File does not exist: bible/matthew/23/matthew_23_28.txt
# File does not exist: bible/matthew/23/matthew_23_29.txt
# File does not exist: bible/matthew/23/matthew_23_30.txt
# File does not exist: bible/matthew/23/matthew_23_31.txt
# File does not exist: bible/matthew/23/matthew_23_32.txt
# File does not exist: bible/matthew/23/matthew_23_33.txt
# File does not exist: bible/matthew/23/matthew_23_34.txt
# File does not exist: bible/matthew/23/matthew_23_35.txt
# File does not exist: bible/matthew/23/matthew_23_36.txt
# File does not exist: bible/matthew/23/matthew_23_37.txt
# File does not exist: bible/matthew/23/matthew_23_38.txt
# File does not exist: bible/matthew/23/matthew_23_39.txt
# File does not exist: bible/matthew/24/matthew_24_1.txt
# File does not exist: bible/matthew/24/matthew_24_2.txt
# File does not exist: bible/matthew/24/matthew_24_3.txt
# File does not exist: bible/matthew/24/matthew_24_4.txt
# File does not exist: bible/matthew/24/matthew_24_5.txt
# File does not exist: bible/matthew/24/matthew_24_6.txt
# File does not exist: bible/matthew/24/matthew_24_7.txt
# File does not exist: bible/matthew/24/matthew_24_8.txt
# File does not exist: bible/matthew/24/matthew_24_9.txt
# File does not exist: bible/matthew/24/matthew_24_10.txt
# File does not exist: bible/matthew/24/matthew_24_11.txt
# File does not exist: bible/matthew/24/matthew_24_12.txt
# File does not exist: bible/matthew/24/matthew_24_13.txt
# File does not exist: bible/matthew/24/matthew_24_14.txt
# File does not exist: bible/matthew/24/matthew_24_15.txt
# File does not exist: bible/matthew/24/matthew_24_16.txt
# File does not exist: bible/matthew/24/matthew_24_17.txt
# File does not exist: bible/matthew/24/matthew_24_18.txt
# File does not exist: bible/matthew/24/matthew_24_19.txt
# File does not exist: bible/matthew/24/matthew_24_20.txt
# File does not exist: bible/matthew/24/matthew_24_21.txt
# File does not exist: bible/matthew/24/matthew_24_22.txt
# File does not exist: bible/matthew/24/matthew_24_23.txt
# File does not exist: bible/matthew/24/matthew_24_24.txt
# File does not exist: bible/matthew/24/matthew_24_25.txt
# File does not exist: bible/matthew/24/matthew_24_26.txt
# File does not exist: bible/matthew/24/matthew_24_27.txt
# File does not exist: bible/matthew/24/matthew_24_28.txt
# File does not exist: bible/matthew/24/matthew_24_29.txt
# File does not exist: bible/matthew/24/matthew_24_30.txt
# File does not exist: bible/matthew/24/matthew_24_31.txt
# File does not exist: bible/matthew/24/matthew_24_32.txt
# File does not exist: bible/matthew/24/matthew_24_33.txt
# File does not exist: bible/matthew/24/matthew_24_34.txt
# File does not exist: bible/matthew/24/matthew_24_35.txt
# File does not exist: bible/matthew/24/matthew_24_36.txt
# File does not exist: bible/matthew/24/matthew_24_37.txt
# File does not exist: bible/matthew/24/matthew_24_38.txt
# File does not exist: bible/matthew/24/matthew_24_39.txt
# File does not exist: bible/matthew/24/matthew_24_40.txt
# File does not exist: bible/matthew/24/matthew_24_41.txt
# File does not exist: bible/matthew/24/matthew_24_42.txt
# File does not exist: bible/matthew/24/matthew_24_43.txt
# File does not exist: bible/matthew/24/matthew_24_44.txt
# File does not exist: bible/matthew/24/matthew_24_45.txt
# File does not exist: bible/matthew/24/matthew_24_46.txt
# File does not exist: bible/matthew/24/matthew_24_47.txt
# File does not exist: bible/matthew/24/matthew_24_48.txt
# File does not exist: bible/matthew/24/matthew_24_49.txt
# File does not exist: bible/matthew/24/matthew_24_50.txt
# File does not exist: bible/matthew/24/matthew_24_51.txt
# File does not exist: bible/matthew/25/matthew_25_1.txt
# File does not exist: bible/matthew/25/matthew_25_2.txt
# File does not exist: bible/matthew/25/matthew_25_3.txt
# File does not exist: bible/matthew/25/matthew_25_4.txt
# File does not exist: bible/matthew/25/matthew_25_5.txt
# File does not exist: bible/matthew/25/matthew_25_6.txt
# File does not exist: bible/matthew/25/matthew_25_7.txt
# File does not exist: bible/matthew/25/matthew_25_8.txt
# File does not exist: bible/matthew/25/matthew_25_9.txt
# File does not exist: bible/matthew/25/matthew_25_10.txt
# File does not exist: bible/matthew/25/matthew_25_11.txt
# File does not exist: bible/matthew/25/matthew_25_12.txt
# File does not exist: bible/matthew/25/matthew_25_13.txt
# File does not exist: bible/matthew/25/matthew_25_14.txt
# File does not exist: bible/matthew/25/matthew_25_15.txt
# File does not exist: bible/matthew/25/matthew_25_16.txt
# File does not exist: bible/matthew/25/matthew_25_17.txt
# File does not exist: bible/matthew/25/matthew_25_18.txt
# File does not exist: bible/matthew/25/matthew_25_19.txt
# File does not exist: bible/matthew/25/matthew_25_20.txt
# File does not exist: bible/matthew/25/matthew_25_21.txt
# File does not exist: bible/matthew/25/matthew_25_22.txt
# File does not exist: bible/matthew/25/matthew_25_23.txt
# File does not exist: bible/matthew/25/matthew_25_24.txt
# File does not exist: bible/matthew/25/matthew_25_25.txt
# File does not exist: bible/matthew/25/matthew_25_26.txt
# File does not exist: bible/matthew/25/matthew_25_27.txt
# File does not exist: bible/matthew/25/matthew_25_28.txt
# File does not exist: bible/matthew/25/matthew_25_29.txt
# File does not exist: bible/matthew/25/matthew_25_30.txt
# File does not exist: bible/matthew/25/matthew_25_31.txt
# File does not exist: bible/matthew/25/matthew_25_32.txt
# File does not exist: bible/matthew/25/matthew_25_33.txt
# File does not exist: bible/matthew/25/matthew_25_34.txt
# File does not exist: bible/matthew/25/matthew_25_35.txt
# File does not exist: bible/matthew/25/matthew_25_36.txt
# File does not exist: bible/matthew/25/matthew_25_37.txt
# File does not exist: bible/matthew/25/matthew_25_38.txt
# File does not exist: bible/matthew/25/matthew_25_39.txt
# File does not exist: bible/matthew/25/matthew_25_40.txt
# File does not exist: bible/matthew/25/matthew_25_41.txt
# File does not exist: bible/matthew/25/matthew_25_42.txt
# File does not exist: bible/matthew/25/matthew_25_43.txt
# File does not exist: bible/matthew/25/matthew_25_44.txt
# File does not exist: bible/matthew/25/matthew_25_45.txt
# File does not exist: bible/matthew/25/matthew_25_46.txt
# File does not exist: bible/matthew/26/matthew_26_1.txt
# File does not exist: bible/matthew/26/matthew_26_2.txt
# File does not exist: bible/matthew/26/matthew_26_3.txt
# File does not exist: bible/matthew/26/matthew_26_4.txt
# File does not exist: bible/matthew/26/matthew_26_5.txt
# File does not exist: bible/matthew/26/matthew_26_6.txt
# File does not exist: bible/matthew/26/matthew_26_7.txt
# File does not exist: bible/matthew/26/matthew_26_8.txt
# File does not exist: bible/matthew/26/matthew_26_9.txt
# File does not exist: bible/matthew/26/matthew_26_10.txt
# File does not exist: bible/matthew/26/matthew_26_11.txt
# File does not exist: bible/matthew/26/matthew_26_12.txt
# File does not exist: bible/matthew/26/matthew_26_13.txt
# File does not exist: bible/matthew/26/matthew_26_14.txt
# File does not exist: bible/matthew/26/matthew_26_15.txt
# File does not exist: bible/matthew/26/matthew_26_16.txt
# File does not exist: bible/matthew/26/matthew_26_17.txt
# File does not exist: bible/matthew/26/matthew_26_18.txt
# File does not exist: bible/matthew/26/matthew_26_19.txt
# File does not exist: bible/matthew/26/matthew_26_20.txt
# File does not exist: bible/matthew/26/matthew_26_21.txt
# File does not exist: bible/matthew/26/matthew_26_22.txt
# File does not exist: bible/matthew/26/matthew_26_23.txt
# File does not exist: bible/matthew/26/matthew_26_24.txt
# File does not exist: bible/matthew/26/matthew_26_25.txt
# File does not exist: bible/matthew/26/matthew_26_26.txt
# File does not exist: bible/matthew/26/matthew_26_27.txt
# File does not exist: bible/matthew/26/matthew_26_28.txt
# File does not exist: bible/matthew/26/matthew_26_29.txt
# File does not exist: bible/matthew/26/matthew_26_30.txt
# File does not exist: bible/matthew/26/matthew_26_31.txt
# File does not exist: bible/matthew/26/matthew_26_32.txt
# File does not exist: bible/matthew/26/matthew_26_33.txt
# File does not exist: bible/matthew/26/matthew_26_34.txt
# File does not exist: bible/matthew/26/matthew_26_35.txt
# File does not exist: bible/matthew/26/matthew_26_36.txt
# File does not exist: bible/matthew/26/matthew_26_37.txt
# File does not exist: bible/matthew/26/matthew_26_38.txt
# File does not exist: bible/matthew/26/matthew_26_39.txt
# File does not exist: bible/matthew/26/matthew_26_40.txt
# File does not exist: bible/matthew/26/matthew_26_41.txt
# File does not exist: bible/matthew/26/matthew_26_42.txt
# File does not exist: bible/matthew/26/matthew_26_43.txt
# File does not exist: bible/matthew/26/matthew_26_44.txt
# File does not exist: bible/matthew/26/matthew_26_45.txt
# File does not exist: bible/matthew/26/matthew_26_46.txt
# File does not exist: bible/matthew/26/matthew_26_47.txt
# File does not exist: bible/matthew/26/matthew_26_48.txt
# File does not exist: bible/matthew/26/matthew_26_49.txt
# File does not exist: bible/matthew/26/matthew_26_50.txt
# File does not exist: bible/matthew/26/matthew_26_51.txt
# File does not exist: bible/matthew/26/matthew_26_52.txt
# File does not exist: bible/matthew/26/matthew_26_53.txt
# File does not exist: bible/matthew/26/matthew_26_54.txt
# File does not exist: bible/matthew/26/matthew_26_55.txt
# File does not exist: bible/matthew/26/matthew_26_56.txt
# File does not exist: bible/matthew/26/matthew_26_57.txt
# File does not exist: bible/matthew/26/matthew_26_58.txt
# File does not exist: bible/matthew/26/matthew_26_59.txt
# File does not exist: bible/matthew/26/matthew_26_60.txt
# File does not exist: bible/matthew/26/matthew_26_61.txt
# File does not exist: bible/matthew/26/matthew_26_62.txt
# File does not exist: bible/matthew/26/matthew_26_63.txt
# File does not exist: bible/matthew/26/matthew_26_64.txt
# File does not exist: bible/matthew/26/matthew_26_65.txt
# File does not exist: bible/matthew/26/matthew_26_66.txt
# File does not exist: bible/matthew/26/matthew_26_67.txt
# File does not exist: bible/matthew/26/matthew_26_68.txt
# File does not exist: bible/matthew/26/matthew_26_69.txt
# File does not exist: bible/matthew/26/matthew_26_70.txt
# File does not exist: bible/matthew/26/matthew_26_71.txt
# File does not exist: bible/matthew/26/matthew_26_72.txt
# File does not exist: bible/matthew/26/matthew_26_73.txt
# File does not exist: bible/matthew/26/matthew_26_74.txt
# File does not exist: bible/matthew/26/matthew_26_75.txt
# File does not exist: bible/matthew/27/matthew_27_1.txt
# File does not exist: bible/matthew/27/matthew_27_2.txt
# File does not exist: bible/matthew/27/matthew_27_3.txt
# File does not exist: bible/matthew/27/matthew_27_4.txt
# File does not exist: bible/matthew/27/matthew_27_5.txt
# File does not exist: bible/matthew/27/matthew_27_6.txt
# File does not exist: bible/matthew/27/matthew_27_7.txt
# File does not exist: bible/matthew/27/matthew_27_8.txt
# File does not exist: bible/matthew/27/matthew_27_9.txt
# File does not exist: bible/matthew/27/matthew_27_10.txt
# File does not exist: bible/matthew/27/matthew_27_11.txt
# File does not exist: bible/matthew/27/matthew_27_12.txt
# File does not exist: bible/matthew/27/matthew_27_13.txt
# File does not exist: bible/matthew/27/matthew_27_14.txt
# File does not exist: bible/matthew/27/matthew_27_15.txt
# File does not exist: bible/matthew/27/matthew_27_16.txt
# File does not exist: bible/matthew/27/matthew_27_17.txt
# File does not exist: bible/matthew/27/matthew_27_18.txt
# File does not exist: bible/matthew/27/matthew_27_19.txt
# File does not exist: bible/matthew/27/matthew_27_20.txt
# File does not exist: bible/matthew/27/matthew_27_21.txt
# File does not exist: bible/matthew/27/matthew_27_22.txt
# File does not exist: bible/matthew/27/matthew_27_23.txt
# File does not exist: bible/matthew/27/matthew_27_24.txt
# File does not exist: bible/matthew/27/matthew_27_25.txt
# File does not exist: bible/matthew/27/matthew_27_26.txt
# File does not exist: bible/matthew/27/matthew_27_27.txt
# File does not exist: bible/matthew/27/matthew_27_28.txt
# File does not exist: bible/matthew/27/matthew_27_29.txt
# File does not exist: bible/matthew/27/matthew_27_30.txt
# File does not exist: bible/matthew/27/matthew_27_31.txt
# File does not exist: bible/matthew/27/matthew_27_32.txt
# File does not exist: bible/matthew/27/matthew_27_33.txt
# File does not exist: bible/matthew/27/matthew_27_34.txt
# File does not exist: bible/matthew/27/matthew_27_35.txt
# File does not exist: bible/matthew/27/matthew_27_36.txt
# File does not exist: bible/matthew/27/matthew_27_37.txt
# File does not exist: bible/matthew/27/matthew_27_38.txt
# File does not exist: bible/matthew/27/matthew_27_39.txt
# File does not exist: bible/matthew/27/matthew_27_40.txt
# File does not exist: bible/matthew/27/matthew_27_41.txt
# File does not exist: bible/matthew/27/matthew_27_42.txt
# File does not exist: bible/matthew/27/matthew_27_43.txt
# File does not exist: bible/matthew/27/matthew_27_44.txt
# File does not exist: bible/matthew/27/matthew_27_45.txt
# File does not exist: bible/matthew/27/matthew_27_46.txt
# File does not exist: bible/matthew/27/matthew_27_47.txt
# File does not exist: bible/matthew/27/matthew_27_48.txt
# File does not exist: bible/matthew/27/matthew_27_49.txt
# File does not exist: bible/matthew/27/matthew_27_50.txt
# File does not exist: bible/matthew/27/matthew_27_51.txt
# File does not exist: bible/matthew/27/matthew_27_52.txt
# File does not exist: bible/matthew/27/matthew_27_53.txt
# File does not exist: bible/matthew/27/matthew_27_54.txt
# File does not exist: bible/matthew/27/matthew_27_55.txt
# File does not exist: bible/matthew/27/matthew_27_56.txt
# File does not exist: bible/matthew/27/matthew_27_57.txt
# File does not exist: bible/matthew/27/matthew_27_58.txt
# File does not exist: bible/matthew/27/matthew_27_59.txt
# File does not exist: bible/matthew/27/matthew_27_60.txt
# File does not exist: bible/matthew/27/matthew_27_61.txt
# File does not exist: bible/matthew/27/matthew_27_62.txt
# File does not exist: bible/matthew/27/matthew_27_63.txt
# File does not exist: bible/matthew/27/matthew_27_64.txt
# File does not exist: bible/matthew/27/matthew_27_65.txt
# File does not exist: bible/matthew/27/matthew_27_66.txt
# File does not exist: bible/matthew/28/matthew_28_1.txt
# File does not exist: bible/matthew/28/matthew_28_2.txt
# File does not exist: bible/matthew/28/matthew_28_3.txt
# File does not exist: bible/matthew/28/matthew_28_4.txt
# File does not exist: bible/matthew/28/matthew_28_5.txt
# File does not exist: bible/matthew/28/matthew_28_6.txt
# File does not exist: bible/matthew/28/matthew_28_7.txt
# File does not exist: bible/matthew/28/matthew_28_8.txt
# File does not exist: bible/matthew/28/matthew_28_9.txt
# File does not exist: bible/matthew/28/matthew_28_10.txt
# File does not exist: bible/matthew/28/matthew_28_11.txt
# File does not exist: bible/matthew/28/matthew_28_12.txt
# File does not exist: bible/matthew/28/matthew_28_13.txt
# File does not exist: bible/matthew/28/matthew_28_14.txt
# File does not exist: bible/matthew/28/matthew_28_15.txt
# File does not exist: bible/matthew/28/matthew_28_16.txt
# File does not exist: bible/matthew/28/matthew_28_17.txt
# File does not exist: bible/matthew/28/matthew_28_18.txt
# File does not exist: bible/matthew/28/matthew_28_19.txt
# File does not exist: bible/matthew/28/matthew_28_20.txt

# %%
curchap = 18
data = process_book_full(
    "luke",
    strongs_g,
    lv_g,
    ex_list,
    curchap,
    curchap+1
)

# %% [markdown]
# ## debug

# %%
len(data)
# Out:
# 31

# %%
data

# %% [markdown]
# ## template style

# %%
jumbo ="""
def data_to_html_render(data):
    if len(data) < 1: 
        return False
    if not data[0].get('book', None) \
    or not data[0].get('chapter', None) \
    or not data[0].get('verse', None) \
    or not data[0].get('greek_text', None):
        print ("wrong data format, missing book chapter verse greek text")
        return False
    chapFull = False
    currchapter = []
    currbook = data[0].get('book', None)
    currchap = data[0].get('chapter', None)
    maxverse = data[0].get('verse', None)
    html = ""
    for n, i in enumerate(data):
        if i.get('book', None) == currbook and i.get('chapter', None) == currchap:
            maxverse = i.get('verse', maxverse)
"""

def chapter_to_html_render(data):
    if not data or len(data) < 1: 
        return ""

    # CSS updated with tooltip support and a cleaner table look
    css = """
    <style>
        body { font-family: 'Segoe UI', Tahoma, sans-serif; line-height: 1.6; color: #333; max-width: 1600px; margin: 0 auto; padding: 20px; background-color: #f8f9fa; }
        h1 { text-align: center; color: #2c3e50; border-bottom: 2px solid #3498db; padding-bottom: 10px; }
        .verse-container { background-color: white; border-radius: 10px; box-shadow: 0 4px 8px rgba(0,0,0,0.1); margin-bottom: 40px; padding: 25px; border-left: 5px solid #3498db; }
        .verse-header { font-weight: bold; color: #2c3e50; background-color: #ecf0f1; padding: 8px 15px; border-radius: 20px; margin-bottom: 15px; }
        .verse-lines { display: flex; flex-wrap: wrap; gap: 15px; margin-bottom: 20px; }
        .line-box { flex: 1 1 45%; min-width: 300px; }
        .line-label { font-weight: bold; color: #16a085; margin-bottom: 5px; }
        .line-content { background-color: #f0f7f4; padding: 12px; border-radius: 8px; border: 1px solid #bdc3c7; font-size: 1.1em; }
        .greek-line { background-color: #f0f0f0; font-family: 'Times New Roman', serif; }
        
        /* Table Styles */
        .mapping-table { width: 100%; border-collapse: collapse; margin-top: 15px; font-size: 0.9em; }
        .mapping-table th { background-color: #3498db; color: white; padding: 12px; text-align: left; position: sticky; top: 0; }
        .mapping-table td { padding: 10px; border-bottom: 1px solid #ddd; vertical-align: top; }
        
        .greek-word { font-weight: bold; color: #8e44ad; font-size: 1.1em; }
        .greek-form { color: #7f8c8d; font-weight: normal; font-size: 0.85em; }
        .latvian-word { font-weight: bold; color: #27ae60; }
        
        /* Morphology Tooltip Style */
        .morph-info { 
            font-style: italic; 
            color: #e67e22; 
            cursor: text; 
            border-bottom: 1px dotted #e67e22; 
            display: inline-block;
        }
        .definition-cell { color: #555; font-size: 0.85em; line-height: 1.3; max-width: 400px; }
        .index-badge { display: inline-block; width: 25px; height: 25px; background-color: #e74c3c; color: white; border-radius: 50%; text-align: center; line-height: 25px; margin-right: 8px; }
    </style>
    """

    book_title = data[0].get('book', 'Bible').capitalize()
    chapter = data[0].get('chapter', '')
    html = f"<!DOCTYPE html><html><head><meta charset='UTF-8'>{css}</head><body>"
    html += f"<h1>📖 {book_title} Chapter {chapter}</h1>"

    for verse_data in data:
        v_num = verse_data.get('verse')
        locus = f"{book_title} {chapter}:{v_num}"
        
        html += f'<div class="verse-container">'
        html += f'<div class="verse-header"><span class="index-badge">{v_num}</span> {locus}</div>'
        
        # ... (text lines remain the same) ...
        html += f'''
        <div class="verse-lines">
            <div class="line-box">
                <div class="line-label">🇬🇷 Greek:</div>
                <div class="line-content greek-line">{verse_data.get('greek_text', '')}</div>
            </div>
            <div class="line-box">
                <div class="line-label">🇱🇻 Latvian:</div>
                <div class="line-content">{verse_data.get('latvian_text', '')}</div>
            </div>
        </div>
        '''

        html += '''<table class="mapping-table"><thead><tr>
                    <th>Greek (Form)</th><th>Latvian</th><th>Strong's</th><th>Morphology</th><th>Definition</th>
                </tr></thead><tbody>'''

        for m in verse_data.get('mappings', []):
            lv_words = ", ".join(m.get('latvian', [])) if m.get('latvian') else "-"
            strong = f"G{m.get('strong_num')}" if m.get('strong_num') else "-"
            
            # 1. Parse the morphology for the tooltip
            raw_morph = m.get('strong_en_title', '')
            morph_dict = parse_morph_code(raw_morph)
            # Create a comma-separated string of the full names
            #full_desc = ", ".join([f"{k}: {v}" for k, v in morph_dict.items() if v])
            full_desc = ", ".join([f"{k.replace('_', ' ').lower()}: {v.title()}" for k, v in morph_dict.items() if v])

            #form ir no strongs dataseta, kamēr greek ir no LLM atbildes citāts; lai gan jāsakrīt, tomēr labāk sets.
            #morph saite pagaidām placeholders no blueletterbible
            html += f'''
                <tr>
                    <td class="greek-word">
                        {m.get('form', '')} <span class="greek-form">({m.get('translit', '')})</span>
                    </td>
                    <td class="latvian-word">{lv_words}</td>
                    <td><a href="https://www.blueletterbible.org/lexicon/{strong.lower()}/" target="_blank">{strong}</a></td>
                    <td>
                        <span class="morph-info" title="{full_desc}">{raw_morph}</span>
                    </td>
                    <td class="definition-cell">{m.get('translit_title', '')}</td>
                </tr>
            '''
        if(len(verse_data.get('leftover_latvian', []))>0):
            html += f'''
                <tr>
                    <td>
                    <span class="greek-form">- (no match)</span>
                    </td>
                    <td colspan="4">
                        {" ,".join(verse_data.get('leftover_latvian', []))}
                    </td>
                </tr>
            '''
        html += "</tbody></table></div>"

    html += "</body></html>"
    return html

# %% [markdown]
# ## loop

# %%
#print(data_to_html_render(data))
#with open(f"{Path("bible") / str(b) / f'{chapter}.html'}", "w", encoding="utf-8") as f:
books = {}
for n, i in enumerate(data):
    bk = i.get("book", None)
    ch = i.get("chapter", None)
    if not bk or not ch:
        continue
    if not books.get(bk, None):
        books[bk] = {}
    if not books[bk].get(ch, None):
        books[bk][ch] = []
    #sorted would be nice wouldnt it with a lambda return i.get("verse", -1) but it seems to be sorted already..
    books[bk][ch].append(i)

for bk, v in books.items():
    for ch, vv in v.items():
        with open(Path("bible") / str(bk) / f"{ch}.html", "w", encoding="utf-8") as f:
            f.write(chapter_to_html_render(vv))
