# %% [markdown]
# # html head common

# %%
html_header="""
<!DOCTYPE html>
<html lang="en">
<head>
    <meta charset="UTF-8">
    <meta name="viewport" content="width=device-width, initial-scale=1.0">
    <title>Greek-Latvian Word-Level Mapping (Matthew 1)</title>
    <style>
        body {
            font-family: 'Segoe UI', Tahoma, Geneva, Verdana, sans-serif;
            line-height: 1.6;
            color: #333;
            max-width: 1200px;
            margin: 0 auto;
            padding: 20px;
            background-color: #f8f9fa;
        }
        h1 {
            text-align: center;
            color: #2c3e50;
            border-bottom: 2px solid #3498db;
            padding-bottom: 10px;
            margin-bottom: 30px;
        }
        .verse-container {
            background-color: white;
            border-radius: 10px;
            box-shadow: 0 4px 8px rgba(0,0,0,0.1);
            margin-bottom: 30px;
            padding: 20px;
            border-left: 5px solid #3498db;
        }
        .verse-header {
            display: flex;
            justify-content: space-between;
            margin-bottom: 15px;
            font-weight: bold;
            color: #2c3e50;
            background-color: #ecf0f1;
            padding: 8px 15px;
            border-radius: 20px;
        }
        .verse-lines {
            display: flex;
            flex-wrap: wrap;
            gap: 15px;
            margin-bottom: 20px;
        }
        .line-box {
            flex: 1 1 45%;
            min-width: 300px;
        }
        .line-label {
            font-weight: bold;
            color: #16a085;
            margin-bottom: 5px;
        }
        .line-content {
            background-color: #f0f7f4;
            padding: 12px;
            border-radius: 8px;
            border: 1px solid #bdc3c7;
            font-size: 1.1em;
        }
        .greek-line {
            background-color: #f0f0f0;
        }
        .mapping-table {
            width: 100%;
            border-collapse: collapse;
            margin-top: 15px;
            font-size: 0.95em;
        }
        .mapping-table th {
            background-color: #3498db;
            color: white;
            padding: 10px;
            text-align: left;
            font-weight: 600;
        }
        .mapping-table td {
            padding: 10px;
            border-bottom: 1px solid #ddd;
            vertical-align: top;
        }
        .mapping-table tr:nth-child(even) {
            background-color: #f9f9f9;
        }
        .mapping-table tr:hover {
            background-color: #f1f9ff;
        }
        .greek-word {
            font-weight: bold;
            color: #8e44ad;
        }
        .latvian-word {
            font-weight: bold;
            color: #27ae60;
        }
        .punctuation {
            color: #7f8c8d;
            font-weight: normal;
        }
        .word-pair {
            display: flex;
            flex-direction: column;
        }
        .footer {
            text-align: center;
            margin-top: 40px;
            padding: 20px;
            color: #7f8c8d;
            border-top: 1px solid #bdc3c7;
        }
        .index-badge {
            display: inline-block;
            width: 25px;
            height: 25px;
            background-color: #e74c3c;
            color: white;
            border-radius: 50%;
            text-align: center;
            line-height: 25px;
            font-size: 0.8em;
            margin-right: 8px;
        }
        .note {
            background-color: #fff3cd;
            border: 1px solid #ffeeba;
            padding: 10px;
            border-radius: 5px;
            margin: 10px 0;
            color: #856404;
        }
    </style>
</head>
<body>

"""
print("header assigned")
# Out:
# header assigned

# %%
def html_01(chapter, summary):
    return f"<h1>📖 Grieķu-Latviešu Vārdu Līmeņu atbilstības ({chapter})</h1> \n\
<p style=\"text-align:center;color:#555;\">{summary}</p>"

#print(html_01("aaaaaaa", "basdfasdfadsf"))

def html_02():
    return """
<div class="legend">
    <h3>🔑 Morphology Legend</h3>
    <div class="legend-grid">
        <div class="legend-item"><span class="morph pos">POS</span> — part of speech</div>
        <div class="legend-item"><span class="morph tense">Tense</span>: Pres / Aor / Imperf / Fut / Perf / PlPerf</div>
        <div class="legend-item"><span class="morph voice">Voice</span>: Act / Mid / Pass / MP</div>
        <div class="legend-item"><span class="morph mood">Mood</span>: Ind / Subj / Imp / Inf / Part / Opt</div>
        <div class="legend-item"><span class="morph person">Person</span>: 1/2/3</div>
        <div class="legend-item"><span class="morph number">Number</span>: Sg / Pl</div>
        <div class="legend-item"><span class="morph case">Case</span>: Nom / Gen / Dat / Acc / Voc</div>
        <div class="legend-item"><span class="morph gender">Gender</span>: M / F / N</div>
    </div>
</div>
"""

def html_03_verses(chapnumber, chapname, verse_lv, verse_el, j): #j == json
    for n, v in enum(j["verses"]):
        return f"<!-- Pants {n+1} -->\n\
<div class=\"verse-container\">\n\
    <div class=\"verse-header\">\n\
        <span><span class=\"index-badge\">{chapnumber}</span> {chapname} {chapnumber}:{n+1}</span>\n\
    </div>\n\
    <div class=\"verse-lines\">\n\
        <div class=\"line-box\">\n\
            <div class=\"line-label\">🇱🇻 Latviski:</div>\n\
            <div class=\"line-content\">{verse_lv}</div>\n\
        </div>\n\
        <div class=\"line-box\">\n\
            <div class=\"line-label\">🇬🇷 Greek:</div>\n\
            <div class=\"line-content greek-line\">Του δε Ιησου γεννηθεντος εν Βηθλεεμ της Ιουδαιας εν ημεραις Ηρωδου του βασιλεως ιδου μαγοι απο ανατολων παρεγενοντο εις Ιεροσολυμα</div>\n\
        </div>\n\
    </div>\n\
    <table class=\"mapping-table\">\n\
        <thead><tr><th>#</th><th>Greek</th><th>Latvian</th><th>Morphology</th></tr></thead>\n\
        <tbody>\n\
            <tr><td>1</td><td class=\"greek-word\">Του</td><td class=\"null-word\">—</td><td><span class=\"morph\"><span class=\"pos\">Art</span> <span class=\"case\">Gen</span> <span class=\"gender\">M</span> <span class=\"number\">Sg</span></span></td></tr>\n\
        </tbody>\n\
    </table>\n\
</div>"

# %% [markdown]
# # request to ai
